# %% [markdown]
# ## Ridge and LAsso regression

# %% [markdown]
# ### Regression is basically, a comparison or measerment between one dependent variable with the other independent variables.
#
# ### by using the machine learning models we try to plot a line that best fits for the predictions

# %% [markdown]
# ### as example consider a mesurement of mice, where height and weight are being compared.

# %% [markdown]
# ![mouse%20ex.PNG](attachment:mouse%20ex.PNG)

# %% [markdown]
# ### in the above figure, generally for some standard graphs we have formulas to find the best fit line (which tells the exact realationship between variables ), but here, in this case we dont have a  formula to find the best fit line ( which is shown in figure, actually we dont know and needed to find that only).
#
# ### to get the best fit line, here, we are going to use two machine learning methods to approximate this relationship.
#
# ### but first, needed to cut this dataset into training and test datasets, generally, 80 % taken as traininng and 20% taken as test datasets.

# %% [markdown]
# ![mts.PNG](attachment:mts.PNG)

# %% [markdown]
# ### here, in above case it shows trianing and test datasets, with the best fit line, which we have to find actually.

# %% [markdown]
# ![mlr.PNG](attachment:mlr.PNG)

# %% [markdown]
# ### by using the training set of the data and with the linear regression algorithm we tried to make a best fit line, it is almost equal but its not.
#
# ### this line doesnt have the actual flexibility to show the curve of the line, no matter how we try to fit the line, with different slopes and staring varible (c) values, it does not fit.
#
# ### this inability, to capture the exact line with machine learning model is called <h1>bias</h1> .

# %% [markdown]
# ### by using some other machine learning model we may get a cross line goes through each line, and the formula feels so accurate with training dataset like this
#
# ![anmlm.PNG](attachment:anmlm.PNG)

# %% [markdown]
# ### the squiggly line fits the training data set very much. and if we calculate the sum square average of the distences from best fit line to actual point it goes
#
# ![comp1.PNG](attachment:comp1.PNG)

# %% [markdown]
# ### in the means of traing dataset the graph 2 really fits and has no gaps in between. now, if we consider the test dataset
#
# ![cmp2.PNG](attachment:cmp2.PNG)

# %% [markdown]
# ### in the testing dataset the graph 2 is also failed to produced the accurate predictions and the gap between bestfit line and values is really more that graph1. this is called overfitting of the line.
# ### if the line doenst fit in training and test datasets its called underfitting
#
# ### in general, the difference calculated by word varience, which is the difference between fittings in training and test datasets

# %% [markdown]
# ![var.PNG](attachment:var.PNG)

# %% [markdown]
# ### to understand the ridge regression, lets consider some height and weight of a mice on graph

# %% [markdown]
# ![mice1.PNG](attachment:mice1.PNG)

# %% [markdown]
# ### with this kind of graph we can simply perform the linear regression and can write one best fit line easily

# %% [markdown]
# ![mice2.PNG](attachment:mice2.PNG)

# %% [markdown]
# ### but if we have very less training points to predict the line, lets consider only two points from the set

# %% [markdown]
# ![newg1.PNG](attachment:newg1.PNG)

# %% [markdown]
# ### what, if the test dataset or real time values are like the below
#
# ![nog.PNG](attachment:nog.PNG)

# %% [markdown]
# ### with the real values the line we predicted is having so much varience in it, so to reduce the bias and varience, we try to reduce  the slope of the best fit line, this is called ridge regression.

# %% [markdown]
# ![rline.PNG](attachment:rline.PNG)

# %% [markdown]
# ### lets try to get the formula, how it works,
#
# ### generally the formula for linear regression is y=mx+c
#
# ### here, we need to reduce the slope so we add lambda*m^2 (i dont have lambda symbol ;) )

# %% [markdown]
# ![ridfor.PNG](attachment:ridfor.PNG)

# %% [markdown]
# ### here, slope is the value that how much penalty is good for to find the best fit line and lambda is the times of the penalty. lambda can be from 0 to infinity.
#
# ### the much lambda increases, the slope of line decreases.
#
# ### by attempting some numbers on the lambda and comaparing the results, we can know the best fit line.

# %% [markdown]
# ![ridline.PNG](attachment:ridline.PNG)

# %% [markdown]
# ### to understand why we need to reduce the slope, lets consider a graph with high steep. ( steep means large change of y axis in small change of x axis, basically almost a vertical line with little angle).
#
# ![stp1.PNG](attachment:stp1.PNG)

# %% [markdown]
# ![stp2.PNG](attachment:stp2.PNG)

# %% [markdown]
# ![rdmice.PNG](attachment:rdmice.PNG)

# %% [markdown]
# ### the formula for cost function, which we are finding all this time is goes like
#
# ![cstf.PNG](attachment:cstf.PNG)

# %% [markdown]
# ### here y hat is slope formula as explained above (y=mx+c)
